# %%
from personal_finance import cashflow
import pandas as pd

import numpy as np

from thefuzz import fuzz
from thefuzz import process

# %%
cf = cashflow.Cashflow('cashflow.yaml', pd.read_pickle('cashflow.pickle'))

# %%
cf.perform_analysis()
# Out:
# Categorized dataset provided. Skipping categorization.
#                          naam / omschrijving            rekening  \
# datum
# 2023-09-13                   ASR NED OMNIBUS  NL16INGB0007742272
# 2023-09-12     GELDMAAT NACHTEGAALSTRAAT NLD  NL16INGB0007742272
# 2023-09-12     ALBERT HEIJN 1078 UTRECHT NLD  NL16INGB0007742272
# 2023-09-12                        Hr J Bouma  NL16INGB0007742272
# 2023-09-10  Thuisbezorgd.nl via Takeaway.com  NL16INGB0007742272
# ...                                      ...                 ...
# 2014-01-06   Vesta Payment Solutions Limited  NL16INGB0007742272
# 2014-01-03     31-12-13 14:59 BETAALAUTOMAAT  NL16INGB0007742272
# 2014-01-03     31-12-13 14:56 BETAALAUTOMAAT  NL16INGB0007742272
# 2014-01-02       Naar Toprekening 0007742272  NL16INGB0007742272
# 2014-01-02        Van Toprekening 0007742272  NL16INGB0007742272
#
#                  tegenrekening code af bij  bedrag (eur)      mutatiesoort  \
# datum
# ...
