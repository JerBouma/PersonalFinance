# %%
from personalfinance import cashflow_controller

# %%
cf = cashflow_controller.Cashflow('examples/configurations/cashflow_example.yaml')

# %%
cf.perform_analysis()
# Out:
# Reading the Cash Flow Dataset(s)
# Found duplicates in examples/cashflows/cashflow_example.csv. These will be added together.
# Applying Categorization
# Categorizing Transactions: 100%|██████████| 6911/6911 [01:23<00:00, 83.11it/s]
# 90.93% of the cash flow dataset has been categorized.
# The following keywords have not led to any category matches (threshold is 90.00%). Please consider removing or updating these keywords to keep things compact:
# Ibiza (60.00%), Car Rental (70.00%), Walmart (71.00%)
# Creating the Excel Template
# Done! Find the Excel Template here: examples/Cash Flow Overview.xlsx

# %% [markdown]
# You can view the transactions by calling the related DataFrame.

# %%
cf._cash_flow_dataset
# Out:
#                                                      name  value  \
# date
# 2023-09-13           asr - Omitted due to Privacy Reasons  12.20
# 2023-09-12  Albert Heijn - Omitted due to Privacy Reasons -13.26
# 2023-09-12      geldmaat - Omitted due to Privacy Reasons -18.43
# 2023-09-10  thuisbezorgd - Omitted due to Privacy Reasons -12.55
# 2023-09-10          Tinq - Omitted due to Privacy Reasons -53.81
# ...                                                   ...    ...
# 2014-01-06      Vodafone - Omitted due to Privacy Reasons -10.05
# 2014-01-03         C1000 - Omitted due to Privacy Reasons  -2.33
# 2014-01-03         C1000 - Omitted due to Privacy Reasons -13.25
# 2014-01-02   toprekening - Omitted due to Privacy Reasons -54.08
# 2014-01-02   toprekening - Omitted due to Privacy Reasons  40.07
#
#                                               description         category  \
# date
# 2023-09-13           asr - Omitted due to Privacy Reasons           Income
# ...

# %%
print("Weekly Overview")
display(cf._weekly_overview)

print("Monthly Overview")
display(cf._monthly_overview)

print("Quarterly Overview")
display(cf._quarterly_overview)

print("Yearly Overview")
display(cf._yearly_overview)
# Out:
# Weekly Overview
#                         Totals   Income Investing Charity Government  \
# week
# 2013-12-30/2014-01-05   -15.58      0.0       0.0     0.0        0.0
# 2014-01-06/2014-01-12   -10.05      0.0       0.0     0.0        0.0
# 2014-01-13/2014-01-19    17.51      0.0       0.0     0.0        0.0
# 2014-01-20/2014-01-26    95.11   105.32       0.0     0.0        0.0
# 2014-02-03/2014-02-09   -45.32      0.0       0.0     0.0        0.0
# ...                        ...      ...       ...     ...        ...
# 2023-08-14/2023-08-20  -598.65   -10.54       0.0     0.0      -5.23
# 2023-08-21/2023-08-27  3922.47  4250.91       0.0     0.0     -87.28
# 2023-08-28/2023-09-03 -3094.29  -928.98       0.0  -20.13      -30.7
# 2023-09-04/2023-09-10  -620.67    27.16       0.0     0.0      -3.02
# 2023-09-11/2023-09-17   -19.49     12.2       0.0     0.0        0.0
#
#                       Health and Insurance  Housing Study Subscriptions  \
# week
# ...

# %% [markdown]
# Next to that, you can view all related period datasets that are categorized per week, month, quarter and year.

# %%
print("Weekly Cash Flows")
display(cf._weekly_cash_flow_dataset)

print("Monthly Cash Flows")
display(cf._monthly_cash_flow_dataset)

print("Quarterly Cash Flows")
display(cf._quarterly_cash_flow_dataset)

print("Yearly Cash Flows")
display(cf._yearly_cash_flow_dataset)
# Out:
# Weekly Cash Flows
#                                                                            name  \
# week                  date
# 2013-12-30/2014-01-05 2014-01-02   toprekening - Omitted due to Privacy Reasons
#                       2014-01-02   toprekening - Omitted due to Privacy Reasons
#                       2014-01-03         C1000 - Omitted due to Privacy Reasons
#                       2014-01-03         C1000 - Omitted due to Privacy Reasons
# 2014-01-06/2014-01-12 2014-01-06      Vodafone - Omitted due to Privacy Reasons
# ...                                                                         ...
# 2023-09-04/2023-09-10 2023-09-10          Tinq - Omitted due to Privacy Reasons
#                       2023-09-10  JOOP SCHOORL - Omitted due to Privacy Reasons
# 2023-09-11/2023-09-17 2023-09-12  Albert Heijn - Omitted due to Privacy Reasons
#                       2023-09-12      geldmaat - Omitted due to Privacy Reasons
# ...
