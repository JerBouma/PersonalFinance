# %%
from personalfinance import portfolio_controller

# %%
portfolio = portfolio_controller.Portfolio('portfolio.yaml')

# %%
portfolio.read_portfolio_dataset().head(20)
# Out:
#              tijd                         product          isin beurs  \
# datum
# 2023-06-30  15:42                 ISHARES S&P 500  IE0031442068   EAM
# 2023-03-01  14:22  VANECK SEMICONDUCTOR UCITS ETF  IE00BMC38736   MIL
# 2023-03-01  14:24                 ISHARES S&P 500  IE0031442068   EAM
# 2022-12-30  14:00                MULTI NASDAQ 100  LU1829221024   EPA
# 2022-12-30  13:51                 VANGUARD S&P500  IE00B3XXRP09   EAM
# 2022-12-30  13:47  VANECK SEMICONDUCTOR UCITS ETF  IE00BMC38736   MIL
# 2022-12-30  13:47                VANGUARD FTSE AW  IE00B3RBWM25   EAM
# 2022-12-30  13:47              ISHARES MSCI WOR A  IE00B4L5Y983   EAM
# 2022-12-01  12:22              ISHARES MSCI WOR A  IE00B4L5Y983   EAM
# 2022-12-01  12:22                 VANGUARD S&P500  IE00B3XXRP09   EAM
# 2022-12-01  12:23                MULTI NASDAQ 100  LU1829221024   EPA
# 2022-12-01  12:23                VANGUARD FTSE AW  IE00B3RBWM25   EAM
# ...
